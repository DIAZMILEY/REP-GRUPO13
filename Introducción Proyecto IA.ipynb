# %% [markdown]
# # Diplomado en inteligencia artificial Universidad Nacional de Colombia Marzo 2021

# %% [markdown]
# #### Grupo número 13
# - Edwin Leonardo Buitrago
# - Juan Carlos Morales
# - Leidy Díaz
# - Freddy Cardozo

# %% [markdown]
# # Introducción
#
# En la actualidad una de las técnicas de aprendizaje automático más utilizada es el procesamiento del lenguaje natural **NLP**, el presente proyecto se enfoca en implementar dichas técnicas para tratar de describir y entender los sentimientos expresados por los usuarios de seis aerolíneas estadounidenses a través de la red social Twitter. La herramienta con la cual se implementara el procesamiento y las técnicas inicialmente mencionadas es **Python** sobre la plataforma open source **Google Colaboratory**.

# %% [markdown]
# # Alcance

# %% [markdown]
# El siguiente proyecto de inteligencia artificial permite proporcionar información sobre los sentimientos expresados por los usuarios de las principales aerolíneas de EEUU, a través de la red social Twitter. La correcta implementación de las herramientas de aprendizaje automático simplifican la necesidad de entender y poder clasificar nuevos mensajes recibidos, la información que se debe procesar y analizar, se toma del repositorio *Kaggle*.
#
# Dadas las características de la metodología utilizada para el presente documento, podemos garantizar una precisión en las clasificaciones y posterior entendimiento del sentimiento que desemboca en el mensaje final, esto permitirá a las aerolíneas tomar las decisiones pertinentes acerca de los servicios ofrecidos, y así fortalecer los intereses operacionales del negocio.

# %% [markdown]
# # Descripción de los datos

# %% [markdown]
# La base de datos contiene 14.640 registros y 15 variables, cuenta con una variable de etiquetas para cada uno de los mensajes emitidos por los usuarios, lo que permitirá elaborar el un modelo predictivo que se utilice para clasificar los mensajes nuevos en determinada categoría, las que se encuentran definidas son; *Negative*, *Neutral* y *Positive* la variable que contiene la información del mensaje se llama *text*, y es con la que se entrenara el modelo.
# [Fuente base de datos](https://www.kaggle.com/crowdflower/twitter-airline-sentiment).

# %%
# Lectura de los datos
import pandas as pd

df = pd.read_csv (r'C:\Users\USO PERSONAL\Diplomado IA UN\Tweets.csv')
df.head(5)
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# ...

# %%
print('Las variables del conjunto de datos son: \n' ,list(df))
print('La dimensión de la base es: \n',(df.shape))
# Out:
# Las variables del conjunto de datos son:
#  ['tweet_id', 'airline_sentiment', 'airline_sentiment_confidence', 'negativereason', 'negativereason_confidence', 'airline', 'airline_sentiment_gold', 'name', 'negativereason_gold', 'retweet_count', 'text', 'tweet_coord', 'tweet_created', 'tweet_location', 'user_timezone']
# La dimensión de la base es:
#  (14640, 15)

# %%
df.groupby(['airline','airline_sentiment']).size().reset_index(name='count')
# Out:
#            airline airline_sentiment  count
# 0         American          negative   1960
# 1         American           neutral    463
# 2         American          positive    336
# 3            Delta          negative    955
# 4            Delta           neutral    723
# 5            Delta          positive    544
# 6        Southwest          negative   1186
# 7        Southwest           neutral    664
# 8        Southwest          positive    570
# 9       US Airways          negative   2263
# 10      US Airways           neutral    381
# 11      US Airways          positive    269
# 12          United          negative   2633
# 13          United           neutral    697
# 14          United          positive    492
# 15  Virgin America          negative    181
# 16  Virgin America           neutral    171
# 17  Virgin America          positive    152

# %% [markdown]
# # Objetivo General

# %% [markdown]
# Elaborar un algoritmo de procesamiento de lenguaje natural, que permita identificar el sentimiento manifestado por los usuarios de las aerolíneas estadounidenses, a través de la red social **Twitter**.

# %% [markdown]
# ## Objetivos especificos
#
# - Implementar un algoritmo que permita clasificar los sentimientos de los usuarios.
#
# - Realizar un análisis de todos los textos, que permita encontrar las palabras más relevantes o frecuentes, que influyen en la definición del sentimiento hacia el servicio utilizado.
#
# - Generar clústeres de palabras que permitan definir un constructo en función de los sentimientos.
